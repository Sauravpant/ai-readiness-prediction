# %%
import pandas as pd
COLUMNS = [
    "Country",
    "Overall score",
    "Government",
    "Technology Sector",
    "Data and Infrastructure"
]
data_2021=pd.read_excel("../data/2021-Government-AI-Readiness-Index-public-dataset.xlsx",sheet_name="Detailed scores",usecols=COLUMNS,header=1)
print(data_2021.isna().sum())
data_2021.head(10)
data_2022=pd.read_excel("../data/2022-Government-AI-Readiness-Index-public-data.xlsx",sheet_name="Detailed scores",usecols=COLUMNS,header=1)
print(data_2022.isna().sum())
data_2022.head(10)
data_2023=pd.read_excel("../data/2023-Government-AI-Readiness-Index-Public-Indicator-Data.xlsx",sheet_name="Pillar & dimension scores",usecols=['Total score',"Country",
    "Government",
    "Technology Sector",
    "Data and Infrastructure"],header=1)
data_2023.rename(columns={"Total score": "Overall score"}, inplace=True)
print(data_2023.isna().sum())
data_2023.head(10)
data_2024=pd.read_excel("../data/2024-GAIRI-data.xlsx",sheet_name="Scores per pillar and dimension",usecols=['Total',"Country",'Infrastructure',
    'Government','Technology Sector'],header=1)
data_2024.rename(columns={"Total": "Overall score", "Infrastructure": "Data and Infrastructure"}, inplace=True)
print(data_2024.isna().sum())
data_2024.head(10)
common_countries = set(data_2021["Country"]).intersection(
    data_2022["Country"],
    data_2023["Country"],
    data_2024["Country"]
)
print('Total common countries:', len(common_countries))
for country in common_countries:
    if country in ['Nepal','India','Pakistan','Bangladesh','Sri Lanka','Bhutan','Maldives','Afghanistan']: # Check if the country list contains SAARC countries
        print('SAARC COUNTRY:', country)
# Filter datasets to only include common countries
data_2021_common = data_2021[data_2021["Country"].isin(common_countries)].set_index("Country")
data_2022_common = data_2022[data_2022["Country"].isin(common_countries)].set_index("Country")
data_2023_common = data_2023[data_2023["Country"].isin(common_countries)].set_index("Country")
data_2024_common = data_2024[data_2024["Country"].isin(common_countries)].set_index("Country")
combined_df = pd.concat([
    data_2021_common.add_prefix("2021_"),
    data_2022_common.add_prefix("2022_"),
    data_2023_common.add_prefix("2023_"),
    data_2024_common.add_prefix("2024_")
], axis=1)
display(combined_df.head())

#Check if any missing values in the combined dataframe
print(combined_df.isna().sum())
# Reset index to have 'Country' as a column again
combined_df.reset_index(inplace=True)
# Save the combined dataframe to a CSV file
combined_df.to_csv("../data/Combined_Dataset_2021_2024.csv", index=False)
data=pd.read_csv("../data/Combined_Dataset_2021_2024.csv")
data.head()
# Out:
# Country                    0
# Overall score              0
# Government                 0
# Technology Sector          0
# Data and Infrastructure    0
# dtype: int64
# Country                    0
# Overall score              0
# Government                 0
# Technology Sector          0
# Data and Infrastructure    0
# dtype: int64
# Country                    0
# Overall score              0
# Government                 0
# Technology Sector          0
# Data and Infrastructure    0
# dtype: int64
# Country                    0
# Overall score              0
# Government                 0
# Technology Sector          0
# Data and Infrastructure    0
# dtype: int64
# Total common countries: 152
# SAARC COUNTRY: Afghanistan
# SAARC COUNTRY: Sri Lanka
# SAARC COUNTRY: Nepal
# SAARC COUNTRY: Pakistan
# SAARC COUNTRY: India
# SAARC COUNTRY: Maldives
# SAARC COUNTRY: Bangladesh
# SAARC COUNTRY: Bhutan
#                           2021_Overall score  2021_Government  \
# Country
# United States of America           88.159612        88.458142
# Singapore                          82.456813        94.876945
# Finland                            79.233742        88.447368
# Netherlands                        78.506811        80.424014
# Sweden                             78.164611        80.759755
#
#                           2021_Technology Sector  \
# Country
# United States of America               83.307719
# Singapore                              66.692602
# Finland                                63.852136
# Netherlands                            66.174703
# Sweden                                 67.372481
#
#                           2021_Data and Infrastructure  2022_Overall score  \
# Country
# United States of America                     92.712973           85.721338
# Singapore                                    85.800893           84.116260
# Finland                                      85.401723           77.593327
# Netherlands                                  88.921716           75.112283
# Sweden                                       86.361596           73.056062
#
#                           2022_Government  2022_Technology Sector  \
# Country
# United States of America        86.206601               81.673650
# Singapore                       89.679262               68.498240
# Finland                         87.803955               58.705584
# Netherlands                     78.234244               59.940203
# Sweden                          74.032491               61.473336
#
#                           2022_Data and Infrastructure  2023_Overall score  \
# Country
# United States of America                     89.283763           84.796171
# Singapore                                    94.171278           81.970965
# Finland                                      86.270442           77.365141
# Netherlands                                  87.162403           74.468996
# Sweden                                       83.662358           72.554288
#
#                           2023_Government  2023_Technology Sector  \
# Country
# United States of America        86.044650               81.023691
# Singapore                       90.398582               66.191800
# Finland                         88.343668               60.358706
# Netherlands                     78.895862               61.956848
# Sweden                          74.699266               62.706393
#
#                           2023_Data and Infrastructure  2024_Overall score  \
# Country
# United States of America                     87.320172           87.032182
# Singapore                                    89.322512           84.249441
# Finland                                      83.393050           76.484718
# Netherlands                                  82.554278           77.229804
# Sweden                                       80.257204           75.402867
#
#                           2024_Government  2024_Technology Sector  \
# Country
# United States of America        89.257568               80.943829
# Singapore                       90.962032               68.650950
# Finland                         84.855177               60.864522
# Netherlands                     84.575161               60.115238
# Sweden                          80.601595               63.450431
#
#                           2024_Data and Infrastructure
# Country
# United States of America                     88.378778
# Singapore                                    84.610803
# Finland                                      72.601918
# Netherlands                                  79.529390
# Sweden                                       73.552942
# 2021_Overall score              0
# 2021_Government                 0
# 2021_Technology Sector          0
# 2021_Data and Infrastructure    0
# 2022_Overall score              0
# 2022_Government                 0
# 2022_Technology Sector          0
# 2022_Data and Infrastructure    0
# 2023_Overall score              0
# 2023_Government                 0
# 2023_Technology Sector          0
# 2023_Data and Infrastructure    0
# 2024_Overall score              0
# 2024_Government                 0
# 2024_Technology Sector          0
# 2024_Data and Infrastructure    0
# dtype: int64
#                     Country  2021_Overall score  2021_Government  \
# 0  United States of America           88.159612        88.458142
# 1                 Singapore           82.456813        94.876945
# 2                   Finland           79.233742        88.447368
# 3               Netherlands           78.506811        80.424014
# 4                    Sweden           78.164611        80.759755
#
#    2021_Technology Sector  2021_Data and Infrastructure  2022_Overall score  \
# 0               83.307719                     92.712973           85.721338
# 1               66.692602                     85.800893           84.116260
# 2               63.852136                     85.401723           77.593327
# 3               66.174703                     88.921716           75.112283
# 4               67.372481                     86.361596           73.056062
#
#    2022_Government  2022_Technology Sector  2022_Data and Infrastructure  \
# 0        86.206601               81.673650                     89.283763
# 1        89.679262               68.498240                     94.171278
# 2        87.803955               58.705584                     86.270442
# 3        78.234244               59.940203                     87.162403
# 4        74.032491               61.473336                     83.662358
#
#    2023_Overall score  2023_Government  2023_Technology Sector  \
# 0           84.796171        86.044650               81.023691
# 1           81.970965        90.398582               66.191800
# 2           77.365141        88.343668               60.358706
# 3           74.468996        78.895862               61.956848
# 4           72.554288        74.699266               62.706393
#
#    2023_Data and Infrastructure  2024_Overall score  2024_Government  \
# 0                     87.320172           87.032182        89.257568
# 1                     89.322512           84.249441        90.962032
# 2                     83.393050           76.484718        84.855177
# 3                     82.554278           77.229804        84.575161
# 4                     80.257204           75.402867        80.601595
#
#    2024_Technology Sector  2024_Data and Infrastructure
# 0               80.943829                     88.378778
# 1               68.650950                     84.610803
# 2               60.864522                     72.601918
# 3               60.115238                     79.529390
# 4               63.450431                     73.552942
